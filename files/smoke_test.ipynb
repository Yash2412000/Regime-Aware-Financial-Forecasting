# %% [markdown]
# # Smoke test
# Verifies dataset -> model -> train wiring with synthetic data. No internet needed — run this FIRST, especially on Hex where GPU time is shared and you don't want to burn a slot on a broken pipeline.

# %%
from smoke_test import main
main()
